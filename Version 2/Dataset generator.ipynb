# %%
import cv2
import numpy as np
from numpy import random
from tqdm import tqdm
import pickle
import imutils
from skimage.util import random_noise

# %%
view = np.ones((450, 300))*255

# %%
def cvShow(v):
    cv2.imshow("win", v)
    cv2.waitKey(0)

# %%
rand_numbers = random.randint(4)+1
rand_numbers

# %% [markdown]
# cv2.putText(view, "A  B  C  D", (x-6, y-20), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0,0,0))
# cv2.putText(view, "{}".format(sn), (x-40, y+8), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0,0,0))
#
# cv2.circle(view, (int(x*c) + r*j, y), r, (0,0,255), -1)
# cv2.circle(view, (int(x*c) + r*j, y), r, (0,0,255), 2)

# %%
def noisy(image):
    row,col,ch = image.shape
    gauss = np.random.randn(row,col,ch)
    gauss = gauss.reshape(row,col,ch)        
    noisy = image + image * gauss
    return noisy
    
    
def sp_noise(image,prob):
    output = np.zeros(image.shape,np.uint8)
    thres = 1 - prob 
    for i in range(image.shape[0]):
        for j in range(image.shape[1]):
            rdn = random.random()
            if rdn < prob:
                output[i][j] = 0
            elif rdn > thres:
                output[i][j] = 255
            else:
                output[i][j] = image[i][j]
    return output

def gaussian(img):
    gauss = np.random.normal(0,1,img.size)
    gauss = gauss.reshape(img.shape[0],img.shape[1],img.shape[2]).astype('uint8')
    img_gauss = cv2.add(img,gauss)
    return img_gauss

# %%
dic = {}

for i in tqdm(range(2601)):
    view = np.ones((1300, 1000))*255
    values = []

    cv2.rectangle(view, (10, 10), (990, 10+70), (0,0,0), 2)
    cv2.putText(view, "University Of Liberal Arts Bangladesh", (20, 60), cv2.FONT_HERSHEY_COMPLEX_SMALL, 2, (0,0,0))
    cv2.putText(view, "ID NO: ", (20, 100), cv2.FONT_HERSHEY_PLAIN, 1, (0,0,0))
    cv2.putText(view, "DEP : ", (300, 100), cv2.FONT_HERSHEY_PLAIN, 1, (0,0,0))



    cv2.rectangle(view, (400, 100), (400+580, 100+200), (0,0,0), 2) # Rectangle that contains name, batch and ..
    cv2.putText(view, "Name: ", (410, 130), cv2.FONT_HERSHEY_PLAIN, 1, (0,0,0))
    cc_x = 470
    for _ in range(100):
        cv2.circle(view, (cc_x, 130), 1, (0,0,0), -1)
        cc_x+=5

    cv2.putText(view, "Batch: ", (410, 170), cv2.FONT_HERSHEY_PLAIN, 1, (0,0,0))
    cc_x = 470
    for _ in range(100):
        cv2.circle(view, (cc_x, 170), 1, (0,0,0), -1)
        cc_x+=5

    cv2.putText(view, "Mobile number: ", (410, 210), cv2.FONT_HERSHEY_PLAIN, 1, (0,0,0))
    cc_x = 545
    for _ in range(85):
        cv2.circle(view, (cc_x, 210), 1, (0,0,0), -1)
        cc_x+=5

    cv2.putText(view, "Data: ../../..", (870, 250), cv2.FONT_HERSHEY_PLAIN, 1, (0,0,0))


    dep_x = 300
    dep_y = 110
    dep_h = 20
    dep_w = 20

    for _ in range(3): # DEP: squarer  
        cv2.rectangle(view, (dep_x, dep_y), (dep_x+dep_w, dep_y+dep_h), (0,0,0), 1)
        dep_x+=dep_w



    id_x = 25
    id_y = 110
    id_h = 20
    id_w = 20

    for _ in range(9): # Id no: squares
        cv2.rectangle(view, (id_x, id_y), (id_x+id_w, id_y+id_h), (0,0,0), 1)
        id_x+=id_w


    c1 = 35
    c2 = 150
    serial_x = 5
    serial_y = 157
    serial_no = 1
    for ss in range(10): # ID number circles
        if ss == 9:
            cv2.putText(view, "0", (serial_x, serial_y), cv2.FONT_HERSHEY_PLAIN, 1, (0,0,0))
        else:
            cv2.putText(view, "{}".format(serial_no), (serial_x, serial_y), cv2.FONT_HERSHEY_PLAIN, 1, (0,0,0))
        color = np.random.randint(9)
        for rrr in range(9):
            if rrr == color:
                values.append(color+1)
                cv2.circle(view, (c1, c2), 7, (0,0,0), -1)
            else:
                cv2.circle(view, (c1, c2), 7, (0,0,0), 2)
            c1+=20

        serial_y+=25
        serial_no+=1
        c2+=25
        c1 = 35

    dep = np.random.randint(4)

    cv2.putText(view, "CSE: ", (300, 157), cv2.FONT_HERSHEY_PLAIN, 1, (0,0,0))
    if dep == 0:
        cv2.circle(view, (355, 152), 7, (0,0,0), -1)
    else:
        cv2.circle(view, (355, 152), 7, (0,0,0), 2)


    cv2.putText(view, "MSJ: ", (300, 200), cv2.FONT_HERSHEY_PLAIN, 1, (0,0,0))
    if dep == 1:
        cv2.circle(view, (355, 195), 7, (0,0,0), -1)
    else:
        cv2.circle(view, (355, 195), 7, (0,0,0), 2)


    cv2.putText(view, "BBA: ", (300, 250), cv2.FONT_HERSHEY_PLAIN, 1, (0,0,0))
    if dep == 2:
        cv2.circle(view, (355, 238), 7, (0,0,0), -1)
    else:
        cv2.circle(view, (355, 238), 7, (0,0,0), 2)


    cv2.putText(view, "EEE: ", (300, 300), cv2.FONT_HERSHEY_PLAIN, 1, (0,0,0))
    if dep == 3:
        cv2.circle(view, (355, 295), 7, (0,0,0), -1)
    else:
        cv2.circle(view, (355, 295), 7, (0,0,0), 2)   

    values.append(dep+1)

    y_var = 470
    start_x, start_y = 50, y_var
    increment_x, increment_y = 32, 30
    r = 9
    sn = 1

    x_2 = [50, 250, 450, 650, 850]
#     char = ["A", "B", "C", "D"]

    for count,ix in enumerate(x_2):
        for row_2 in range(4):
            for col in range(5):
                if col == 0:
                    cv2.putText(view, "A", (start_x-7, start_y-20), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0,0,0))
                    cv2.putText(view, "B", (start_x+24, start_y-20), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0,0,0))
                    cv2.putText(view, "C", (start_x+56, start_y-20), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0,0,0))
                    cv2.putText(view, "D", (start_x+88, start_y-20), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0,0,0))
                color = np.random.randint(4)
                for rr in range(4):
                    if rr == 0:
                        cv2.putText(view, "{}".format(sn), (start_x-43, start_y+8), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0,0,0))
                        sn+=1

                    if rr == color:
                        values.append(color+1)
                        cv2.circle(view, (start_x, start_y), r, (0,0,0), -1)


                    cv2.circle(view, (start_x, start_y), r, (0,0,0), 2)
#                     cv2.putText(view, "{}".format(char[rr]), (start_x-5, start_y+5), cv2.FONT_HERSHEY_PLAIN, 1, (0,0,0))

                    start_x += increment_x
                start_y+=increment_y
                start_x = ix

            start_x = ix
            start_y += increment_y+20

        start_y = y_var
        if count != len(x_2)-1:
            start_x = x_2[count+1]

#     value = np.array(value)
#     dic["{}.png".format(i)] = value
#     cvShow(view)
#     cv2.imwrite("dataset/{}.png".format(i), view)
    if i <= 2000:

        cv2.imwrite("dataset/train/{}1.png".format(i), view)
        dic["{}1.png".format(i)] = values

    #     view = cv2.imread("dataset/{}1.png".format(i))
    #     view = imutils.rotate(view, -15)
    #     cv2.imwrite("dataset/{}2.png".format(i), view)
    #     dic["{}2.png".format(i)] = values

    #     view = cv2.imread("dataset/{}1.png".format(i))
    #     view = imutils.rotate(view, 15)
    #     cv2.imwrite("dataset/{}3.png".format(i), view)
    #     dic["{}3.png".format(i)] = values

#         view = cv2.imread("dataset/train/{}1.png".format(i))
#         view = imutils.rotate_bound(view, -15)
#         cv2.imwrite("dataset/train/{}4.png".format(i), view)
#         dic["{}4.png".format(i)] = values

#         view = cv2.imread("dataset/train/{}1.png".format(i))
#         view = imutils.rotate_bound(view, 15)
#         cv2.imwrite("dataset/train/{}5.png".format(i), view)
#         dic["{}5.png".format(i)] = values

#         view = cv2.imread("dataset/train/{}1.png".format(i))
#         view = cv2.GaussianBlur(view, (7,7), 7)
#         cv2.imwrite("dataset/train/{}6.png".format(i), view)
#         dic["{}6.png".format(i)] = values

#         view = cv2.imread("dataset/train/{}1.png".format(i))
#         view = sp_noise(view, 0.05)
#         cv2.imwrite("dataset/train/{}7.png".format(i), view)
#         dic["{}7.png".format(i)] = values

#         view = cv2.imread("dataset/train/{}1.png".format(i))
#         view = noisy(view)
#         cv2.imwrite("dataset/train/{}8.png".format(i), view)
#         dic["{}8.png".format(i)] = values

#         view = cv2.imread("dataset/train/{}1.png".format(i))
#         view = gaussian(view)
#         cv2.imwrite("dataset/train/{}9.png".format(i), view)
#         dic["{}9.png".format(i)] = values

#         view = cv2.imread("dataset/train/{}1.png".format(i))
#         h,w,c = view.shape
#         for _ in range(250):
#             wr = np.random.randint(w)
#             hr = np.random.randint(h)
#             cv2.circle(view, (wr,hr), 2, (0,0,0), -1)

#         cv2.imwrite("dataset/train/{}10.png".format(i), view)
#         dic["{}10.png".format(i)] = values
    
    else:
        
        cv2.imwrite("dataset/val/{}1.png".format(i), view)
        dic["{}1.png".format(i)] = values

    #     view = cv2.imread("dataset/{}1.png".format(i))
    #     view = imutils.rotate(view, -15)
    #     cv2.imwrite("dataset/{}2.png".format(i), view)
    #     dic["{}2.png".format(i)] = values

    #     view = cv2.imread("dataset/{}1.png".format(i))
    #     view = imutils.rotate(view, 15)
    #     cv2.imwrite("dataset/{}3.png".format(i), view)
    #     dic["{}3.png".format(i)] = values

#         view = cv2.imread("dataset/val/{}1.png".format(i))
#         view = imutils.rotate_bound(view, -15)
#         cv2.imwrite("dataset/val/{}4.png".format(i), view)
#         dic["{}4.png".format(i)] = values

#         view = cv2.imread("dataset/val/{}1.png".format(i))
#         view = imutils.rotate_bound(view, 15)
#         cv2.imwrite("dataset/val/{}5.png".format(i), view)
#         dic["{}5.png".format(i)] = values

#         view = cv2.imread("dataset/val/{}1.png".format(i))
#         view = cv2.GaussianBlur(view, (7,7), 7)
#         cv2.imwrite("dataset/val/{}6.png".format(i), view)
#         dic["{}6.png".format(i)] = values

#         view = cv2.imread("dataset/val/{}1.png".format(i))
#         view = sp_noise(view, 0.05)
#         cv2.imwrite("dataset/val/{}7.png".format(i), view)
#         dic["{}7.png".format(i)] = values

#         view = cv2.imread("dataset/val/{}1.png".format(i))
#         view = noisy(view)
#         cv2.imwrite("dataset/val/{}8.png".format(i), view)
#         dic["{}8.png".format(i)] = values

#         view = cv2.imread("dataset/val/{}1.png".format(i))
#         view = gaussian(view)
#         cv2.imwrite("dataset/val/{}9.png".format(i), view)
#         dic["{}9.png".format(i)] = values

#         view = cv2.imread("dataset/val/{}1.png".format(i))
#         h,w,c = view.shape
#         for _ in range(250):
#             wr = np.random.randint(w)
#             hr = np.random.randint(h)
#             cv2.circle(view, (wr,hr), 2, (0,0,0), -1)

#         cv2.imwrite("dataset/val/{}10.png".format(i), view)
#         dic["{}10.png".format(i)] = values
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 2601/2601 [00:39<00:00, 66.41it/s]

# %%
len(dic)
# Out:
# 2601

# %%
def parseData(d, key):
    arr = d[key]
    id_num = arr[0:10]
    dep = arr[10]
    mcq = arr[11:]
    return (id_num, dep, mcq)

# %%
id_num, dep, mcq = parseData(dic, "90910.png")

# %%
print(id_num)
print(dep)
print(mcq)

# %%
dic = {}

for k in tqdm(range(1)):
    values = []
    view = np.ones((400, 340))*255
    x, y = 50, 50
    r = 30
    cnst = (r*2) + 15
    for i in range(5):
        color_pos = random.randint(4)
        values.append(i)
        c = 1
        for j in range(4):
            if j == color_pos:
                cv2.circle(view, ((x*c) + r*j, y), r, (0,0,255), -1)
            else:
                cv2.circle(view, ((x*c) + r*j, y), r, (0,0,255), 2)
            c+=1
        y = y + cnst
    
    cv2.imwrite("dataset/{}.png".format(k), view)
    dic["{}.png".format(k)] = values

# %%
with open('dataset_labels.pkl', 'wb') as f:
    pickle.dump(dic, f)

# %%
img = cv2.imread("dataset/0.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
f = np.vsplit(img,5)
for h in f:
    v = np.hsplit(h, 4)
    for i in v:
        print(cv2.countNonZero(i), end = " ")
    print()
